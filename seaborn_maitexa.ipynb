# %% [markdown]
# <a href="https://colab.research.google.com/github/Junaiis/29766junais/blob/main/seaborn_maitexa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex', 'smoker', 'day', 'time'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_style("darkgrid")
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_style("whitegrid")
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_style("ticks")
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_style('dark')
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_style("white")
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_context("paper")
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_context("notebook")
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_context("poster")
plt.scatter(df.total_bill,df.tip)

# %%
sns.set_context("talk")
plt.scatter(df.total_bill,df.tip)

# %%
# despine(for removing lines from side)
plt.scatter(df.total_bill,df.tip)
sns.despine()
plt.show()

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
plt.scatter(df.total_bill,df.tip,palette='viridis')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-63a828b5f202> in <cell line: 1>()
# ----> 1 plt.scatter(df.total_bill,df.tip,palette='viridis')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %%
data = sns.load_dataset("tips")

sns.relplot(data=data, x="total_bill", y="tip", hue="sex",col="day" ,col_wrap=2,height=4, aspect=1)

plt.show()

# %%
sns.countplot(data=data, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='count'>

# %%
sns.displot(data=data, x='total_bill', y='tip',hue='sex',col='day',col_wrap=2, palette='viridis')

# %%
sns.displot(data=data, x = 'total_bill' )

# %%
sns.lineplot(data=data, x='day',y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.kdeplot(data=data, x='total_bill',y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.ecdfplot(data=data, y='tip')
# Out:
# <Axes: xlabel='Proportion', ylabel='tip'>

# %%
sns.pointplot(data=data, x='day',y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data=data, x='day',y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(data=data, x='day',y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data=data, x='day',y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(data=data, x='day',y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
data = np.random.rand(10, 12)
clustermap_data = sns.clustermap(data, cmap='viridis')

# %%
g = sns.FacetGrid(df, col='time', row='sex', margin_titles=True)
g.map(sns.scatterplot, 'total_bill', 'tip')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='reg')

# %%
sns.boxplot(x='day',y='total_bill',data=df,palette='Set2')
# Out:
# <ipython-input-207-52d720cbaff3>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='total_bill',data=df,palette='Set2')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
g = sns.FacetGrid(df, col='day', col_wrap=3, height=3)
g.map(sns.boxplot, 'day', 'total_bill', palette='Set2')


plt.suptitle('Boxplots of Total Bill by Day', y=1.05)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# ...

# %%
# seaborn excersixe
#

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex', 'smoker', 'day', 'time'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
sns.displot(df['total_bill'])

# %%
sns.displot(x='total_bill',data=df)

# %%
sns.boxplot(x='total_bill',y='day',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.countplot(data=df, x='time')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
# sns.countplot(x='time', data=df)

# # Set title and labels
# plt.title('Number of Tips by Time of Day')
# plt.xlabel('Time of Day')
# plt.ylabel('Count')

# plt.show()

# %%
sns.pairplot(df)

# %%
df = sns.load_dataset('tips')

a = df.corr(numeric_only=True)

sns.heatmap(a,annot=True)
# Out:
# <Axes: >

# %%
titanic = sns.load_dataset('titanic')
# create plot
sns.countplot(x = 'class', hue = 'who', data = titanic, palette = 'magma')
plt.title('Survivors')
plt.show()

# %%
sns.countplot(data=df,x='sex',hue='size')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.pointplot(x='tip',y='day',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.pointplot(data=df,x = 'time',y = 'total_bill',hue='smoker')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %%
sns.set_style('darkgrid')
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %%
sns.regplot(data=df,x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.lmplot(x="total_bill", y="tip", data=df,col='sex',col_wra)

# %%
sns.kdeplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("ticks")
sns.pairplot(df,hue = 'total_bill',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %%
sns.pairplot(df,hue = 'tip',diag_kind = "kde",kind = "scatter",palette = "husl")

# %%
sns.violinplot(x='total_bill',y='day',data=df,hue='sex')
plt.show()

# %%
sns.violinplot(x='total_bill',y='day',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.stripplot(x='total_bill',y='day',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.stripplot(x='total_bill',y='day',jitter=True,data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.stripplot(x='total_bill',y='day',data=df,hue='day',jitter=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the 'tips' dataset
tips = sns.load_dataset('tips')

# Create a KDE plot for the 'tip' column
sns.kdeplot(data=tips, x='tip', fill=True)

# Add labels and title
plt.xlabel('Tip Amount')
plt.ylabel('Density')
plt.title('KDE Plot of Tips')

# Show the plot
plt.show()

# %%
sns.kdeplot(x='tip',data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
tips = sns.load_dataset('tips')

a = tips.select_dtypes(include='number')

sns.clustermap(a.corr(), annot=True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
